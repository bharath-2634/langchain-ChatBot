# %%
llm=OpenAI(openai_api_key=os.environ["OPENAI_API_KEY"],temperature=0.6)

# %%
text = "what is the capital of India";
print(llm.predict(text))
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[30], line 2
#       1 text = "what is the capital of India";
# ----> 2 print(llm.predict(text))
#
# File d:\GenAi\LangChain-chatBot\venv\Lib\site-packages\langchain_core\_api\deprecation.py:191, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     189     warned = True
#     190     emit_warning()
# --> 191 return wrapped(*args, **kwargs)
#
# File d:\GenAi\LangChain-chatBot\venv\Lib\site-packages\langchain_core\language_models\llms.py:1354, in BaseLLM.predict(self, text, stop, **kwargs)
#    1348 @deprecated("0.1.7", alternative="invoke", removal="1.0")
#    1349 @override
#    1350 def predict(
#    1351     self, text: str, *, stop: Optional[Sequence[str]] = None, **kwargs: Any
#    1352 ) -> str:
#    1353     _stop = None if stop is None else list(stop)
# ...

# %%
import os
os.environ["OPENAI_API_KEY"]="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"

# %%
from langchain_openai import OpenAI

# %%
os.environ["HUGGINGFACEHUB_API_TOKEN"]="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"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 os.environ["HUGGINGFACEHUB_API_TOKEN"]="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"
#
# NameError: name 'os' is not defined

# %%
from langchain.llms import HuggingFaceHub

llm = HuggingFaceHub(
    repo_id="google/flan-t5-large",
    model_kwargs={"temperature": 0.7, "max_new_tokens": 100},
    huggingfacehub_api_token="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"
)

response = llm.invoke("Tell me about Dhoni.")
print(response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 9
#       1 from langchain.llms import HuggingFaceHub
#       3 llm = HuggingFaceHub(
#       4     repo_id="google/flan-t5-large",
#       5     model_kwargs={"temperature": 0.7, "max_new_tokens": 100},
#       6     huggingfacehub_api_token="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"
#       7 )
# ----> 9 response = llm.invoke("Tell me about Dhoni.")
#      10 print(response)
#
# File d:\GenAi\LangChain-chatBot\venv\Lib\site-packages\langchain_core\language_models\llms.py:387, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     376 @override
#     377 def invoke(
#     378     self,
#    (...)    383     **kwargs: Any,
#     384 ) -> str:
#     385     config = ensure_config(config)
#     386     return (
# --> 387         self.generate_prompt(
#     388             [self._convert_input(input)],
# ...
